# %%
# Cadena de conexión a MongoDB
mongo_connection_string = "mongodb://admin:admin@localhost:27017/"

# Conexión a MongoDB
client = pymongo.MongoClient(mongo_connection_string)

# Seleccionar la base de datos 'valenbici'
db = client['valenbici']

# Seleccionar la colección 'sample_table'
collection = db['sample_table']

# Obtener todos los documentos de la colección
documents = list(collection.find())

# Crear un DataFrame a partir de la lista de documentos
df = pd.DataFrame(documents)

# Cierra la conexión
client.close()

df
# Out:
#                          _id                                       address  \
# 0   656b20645b186e96dc940a5c       Plaza San Felipe Neri (Mercado Algirós)
# 1   656b20645b186e96dc940a5d                      Campoamor - Músico Ginés
# 2   656b20645b186e96dc940a5e      San Vicente Martir - Doctor Vilá Barberá
# 3   656b20645b186e96dc940a5f         Regne de Valencia - Almirante Cadarso
# 4   656b20645b186e96dc940a60                       Alameda - Pintor Maella
# 5   656b20645b186e96dc940a61        Amadeo de Saboya (frente Ayuntamiento)
# 6   656b20645b186e96dc940a62                               Plaza de Europa
# 7   656b20645b186e96dc940a63                              Av. Puerto 61-63
# 8   656b20645b186e96dc940a64                Micer Mascó - Rodriguez Fornos
# 9   656b20645b186e96dc940a65                    Blasco Ibañez - Jaime Roig
# 10  656b20645b186e96dc940a66                             Blasco Ibañez 121
# 11  656b20645b186e96dc940a67              Blasco Ibañez, 32 (F. Filología)
# 12  656b20645b186e96dc940a68                        Blasco Ibañez - Aragón
# 13  656b20645b186e96dc940a69                      Blasco Ibañez - Clariano
# 14  656b20645b186e96dc940a6a                         Blasco Ibañez - Yecla
# 15  656b20645b186e96dc940a6b               Justo y Pastor - Duque de Gaeta
# 16  656b20645b186e96dc940a6c  C/GUILLEM DE CASTRO esquina con C/NA JORDANA
# 17  656b20645b186e96dc940a6d               Plaza del Musico López Chavarri
# 18  656b20645b186e96dc940a6e                       Plaza de la Reina - Mar
# 19  656b20645b186e96dc940a6f                      Huesca - Barón de Cárcer
#
#     number open  available  free  total ticket           updated_at  \
# 0       74    T         14     6     20      T  02/12/2023 13:09:46
# 1       76    T         12     7     19      T  02/12/2023 13:09:46
# 2       27    T          0    20     20      F  02/12/2023 13:09:46
# 3       35    T          0    15     20      T  02/12/2023 13:09:46
# 4       53    T         22     3     25      F  02/12/2023 13:09:46
# 5       80    T         16     9     25      F  02/12/2023 13:09:46
# 6       54    T         17     3     20      T  02/12/2023 13:09:46
# 7       64    T         14     6     20      F  02/12/2023 13:09:46
# 8       81    T         11     9     20      F  02/12/2023 13:09:46
# 9       85    T          7    16     23      F  02/12/2023 13:09:46
# 10      97    T          8    15     23      F  02/12/2023 13:09:46
# 11      90    T          2    38     40      F  02/12/2023 13:09:46
# 12      92    T         14     6     20      T  02/12/2023 13:09:46
# 13      94    T         13     7     20      F  02/12/2023 13:09:46
# 14      96    T         11    10     21      T  02/12/2023 13:09:46
# 15      98    T          3    12     15      T  02/12/2023 13:09:46
# 16       1    T          1    24     25      T  02/12/2023 13:09:46
# 17       3    T          1    18     20      T  02/12/2023 13:09:46
# 18       8    F          4     5      9      T  02/12/2023 13:09:46
# 19      14    T          7    12     20      T  02/12/2023 13:09:46
#
#                                             geo_shape  \
# 0   {'type': 'Feature', 'geometry': {'coordinates'...
# 1   {'type': 'Feature', 'geometry': {'coordinates'...
# 2   {'type': 'Feature', 'geometry': {'coordinates'...
# 3   {'type': 'Feature', 'geometry': {'coordinates'...
# 4   {'type': 'Feature', 'geometry': {'coordinates'...
# 5   {'type': 'Feature', 'geometry': {'coordinates'...
# 6   {'type': 'Feature', 'geometry': {'coordinates'...
# 7   {'type': 'Feature', 'geometry': {'coordinates'...
# 8   {'type': 'Feature', 'geometry': {'coordinates'...
# 9   {'type': 'Feature', 'geometry': {'coordinates'...
# 10  {'type': 'Feature', 'geometry': {'coordinates'...
# 11  {'type': 'Feature', 'geometry': {'coordinates'...
# 12  {'type': 'Feature', 'geometry': {'coordinates'...
# 13  {'type': 'Feature', 'geometry': {'coordinates'...
# 14  {'type': 'Feature', 'geometry': {'coordinates'...
# 15  {'type': 'Feature', 'geometry': {'coordinates'...
# 16  {'type': 'Feature', 'geometry': {'coordinates'...
# 17  {'type': 'Feature', 'geometry': {'coordinates'...
# 18  {'type': 'Feature', 'geometry': {'coordinates'...
# 19  {'type': 'Feature', 'geometry': {'coordinates'...
#
#                                          geo_point_2d
# 0   {'lon': -0.3537343124957471, 'lat': 39.4699493...
# 1   {'lon': -0.343461277578989, 'lat': 39.47008330...
# 2   {'lon': -0.3818514137102655, 'lat': 39.4633622...
# 3   {'lon': -0.36699436340059455, 'lat': 39.463749...
# 4   {'lon': -0.34813930400480075, 'lat': 39.456764...
# 5   {'lon': -0.36229833944736023, 'lat': 39.473742...
# 6   {'lon': -0.3526903171951741, 'lat': 39.4597782...
# 7   {'lon': -0.35419531724959286, 'lat': 39.466518...
# 8   {'lon': -0.36097833354659675, 'lat': 39.475128...
# 9   {'lon': -0.3647153422684407, 'lat': 39.4794643...
# 10  {'lon': -0.3431322739648798, 'lat': 39.4730683...
# 11  {'lon': -0.3589673254467337, 'lat': 39.4767343...
# 12  {'lon': -0.35596831583559707, 'lat': 39.475860...
# 13  {'lon': -0.35158330144926053, 'lat': 39.475378...
# 14  {'lon': -0.3482142912637639, 'lat': 39.4735543...
# 15  {'lon': -0.348442294427372, 'lat': 39.46968030...
# 16  {'lon': -0.38292927973315827, 'lat': 39.480042...
# 17  {'lon': -0.3802883976424855, 'lat': 39.4768353...
# 18  {'lon': -0.3750843825510484, 'lat': 39.4743203...
# 19  {'lon': -0.37972440222295445, 'lat': 39.468967...
